# %%
import pandas as pd
import os
import csv
import sqlite3
import sqlalchemy
from sqlalchemy import create_engine, MetaData

# %%
engine = create_engine("sqlite:///db/cryptocurrency.sqlite")
conn = sqlite3.connect("db/cryptocurrency.sqlite")

# %%
df = pd.read_sql_query("select * from bch", conn)

# %%
df['name'] = 'BCH'
df.head(2)
# Out:
#    measurement_ID  price_close  price_high  price_low  price_open  \
# 0               1       2498.0      2500.0    2432.00     2436.01
# 1               2       2600.0      2895.0    2298.57     2490.63
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-12-29T00:00:00.0000000Z  2017-12-28T00:00:00.0000000Z           689
# 1  2017-12-30T00:00:00.0000000Z  2017-12-29T00:00:00.0000000Z         15691
#
#    volume_traded name
# 0     413.643122  BCH
# 1   11900.499231  BCH

# %%
csv_file = "bch.csv"

# %%
df.to_csv(csv_file, sep='\t')

# %%
df1 = pd.read_sql_query("select * from btc", conn)

# %%
df1['name'] = 'BTC'
df1.head(2)
# Out:
#    measurement_ID  price_close  price_high  price_low  price_open  \
# 0               1       536.95      542.87     525.49      532.37
# 1               2       538.00      540.00     529.13      536.95
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2016-06-02T00:00:00.0000000Z  2016-06-01T00:00:00.0000000Z          4433
# 1  2016-06-03T00:00:00.0000000Z  2016-06-02T00:00:00.0000000Z          3533
#
#    volume_traded name
# 0    5456.942657  BTC
# 1    3939.351328  BTC

# %%
csv1_file = "btc.csv"
df1.to_csv(csv1_file, sep = "\t")

# %%
new_df = df.append(df1, ignore_index=True)
new_df.tail(2)
# Out:
#      measurement_ID  price_close  price_high  price_low  price_open  \
# 198              99       615.16      615.92     604.70      608.93
# 199             100       625.67      628.98     611.66      614.44
#
#                   time_period_end             time_period_start  trades_count  \
# 198  2016-09-08T00:00:00.0000000Z  2016-09-07T00:00:00.0000000Z          3531
# 199  2016-09-09T00:00:00.0000000Z  2016-09-08T00:00:00.0000000Z          4029
#
#      volume_traded name
# 198    4502.710727  BTC
# 199    4354.952516  BTC

# %%
df2 = pd.read_sql_query("select * from eth", conn)

# %%
df2['name'] = 'ETH'
df2.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       298.40       298.6     292.30      293.13
# 1      2       319.31       353.0     292.71      297.26
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-08-21T00:00:00.0000000Z  2017-08-20T00:00:00.0000000Z           202
# 1  2017-08-22T00:00:00.0000000Z  2017-08-21T00:00:00.0000000Z          9772
#
#    volume_traded name
# 0     289.702776  ETH
# 1   24750.689250  ETH

# %%
csv2_file = "eth.csv"
df2.to_csv(csv2_file, sep = "\t")

# %%
new_df = new_df.append(df2, ignore_index=True)
new_df.tail(2)
# Out:
#      cc_ID  measurement_ID name  price_close  price_high  price_low  \
# 298   99.0             NaN  ETH       467.00      472.76     438.09
# 299  100.0             NaN  ETH       474.67      487.00     456.24
#
#      price_open               time_period_end             time_period_start  \
# 298      461.89  2017-11-27T00:00:00.0000000Z  2017-11-26T00:00:00.0000000Z
# 299      468.99  2017-11-28T00:00:00.0000000Z  2017-11-27T00:00:00.0000000Z
#
#      trades_count  volume_traded
# 298         10567   29007.052713
# 299         15723   53900.348757

# %%
df3 = pd.read_sql_query("select * from ltc", conn)

# %%
df3['name'] = 'LTC'
df3.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1        42.04       42.99      40.55        41.7
# 1      2        40.50       41.97      39.64        41.8
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-06-29T00:00:00.0000000Z  2017-06-28T00:00:00.0000000Z           811
# 1  2017-06-30T00:00:00.0000000Z  2017-06-29T00:00:00.0000000Z           672
#
#    volume_traded name
# 0   18559.116545  LTC
# 1   14557.531222  LTC

# %%
csv3_file = "ltc.csv"
df3.to_csv(csv3_file, sep = "\t")

# %%
new_df = new_df.append(df3, ignore_index=True)
new_df.tail(2)
# Out:
#      cc_ID  measurement_ID name  price_close  price_high  price_low  \
# 398   99.0             NaN  LTC        51.21       52.92      50.41
# 399  100.0             NaN  LTC        51.74       51.90      50.16
#
#      price_open               time_period_end             time_period_start  \
# 398       52.14  2017-10-05T00:00:00.0000000Z  2017-10-04T00:00:00.0000000Z
# 399       51.06  2017-10-06T00:00:00.0000000Z  2017-10-05T00:00:00.0000000Z
#
#      trades_count  volume_traded
# 398           781   15584.902321
# 399          1147   21258.673612

# %%
df4 = pd.read_sql_query("select * from xrp", conn)

# %%
df4['name'] = 'XRP'
df4.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1      0.00649      0.0065    0.00645     0.00645
# 1      2      0.00638      0.0065    0.00638     0.00650
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-01-26T00:00:00.0000000Z  2017-01-25T00:00:00.0000000Z            52
# 1  2017-01-27T00:00:00.0000000Z  2017-01-26T00:00:00.0000000Z            30
#
#    volume_traded name
# 0  535232.116769  XRP
# 1  366651.319173  XRP

# %%
csv4_file = "xrp.csv"
df4.to_csv(csv4_file, sep = "\t")

# %%
new_df = new_df.append(df4, ignore_index=True)
new_df.tail(2)
# Out:
#      cc_ID  measurement_ID name  price_close  price_high  price_low  \
# 498   99.0             NaN  XRP      0.21022       0.222    0.19510
# 499  100.0             NaN  XRP      0.21714       0.220    0.20755
#
#      price_open               time_period_end             time_period_start  \
# 498     0.20365  2017-05-14T00:00:00.0000000Z  2017-05-13T00:00:00.0000000Z
# 499     0.21060  2017-05-15T00:00:00.0000000Z  2017-05-14T00:00:00.0000000Z
#
#      trades_count  volume_traded
# 498          3075   1.739387e+07
# 499          1358   6.314897e+06

# %%
df5 = pd.read_sql_query("select * from etc", conn)

# %%
df5['name'] = 'ETC'
df5.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       1.7275      1.9659      1.685      1.7943
# 1      2       1.6430      1.7990      1.550      1.7289
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2016-07-29T00:00:00.0000000Z  2016-07-28T00:00:00.0000000Z          4288
# 1  2016-07-30T00:00:00.0000000Z  2016-07-29T00:00:00.0000000Z          8121
#
#    volume_traded name
# 0  194328.318400  ETC
# 1  494860.563079  ETC

# %%
csv5_file = "etc.csv"
df5.to_csv(csv5_file, sep = "\t")

# %%
new_df = new_df.append(df5, ignore_index=True)
new_df.tail(2)
# Out:
#      cc_ID  measurement_ID name  price_close  price_high  price_low  \
# 598   99.0             NaN  ETC      0.91892      0.9624    0.90110
# 599  100.0             NaN  ETC      0.91671      0.9349    0.89883
#
#      price_open               time_period_end             time_period_start  \
# 598      0.9179  2016-11-11T00:00:00.0000000Z  2016-11-10T00:00:00.0000000Z
# 599      0.9211  2016-11-12T00:00:00.0000000Z  2016-11-11T00:00:00.0000000Z
#
#      trades_count  volume_traded
# 598           264   47833.806007
# 599           169   27801.183802

# %%
df6 = pd.read_sql_query("select * from neo", conn)

# %%
df6['name'] = 'NEO'
df6.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1        31.15       39.80     28.144      34.950
# 1      2        25.89       31.39     22.320      31.003
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-09-08T00:00:00.0000000Z  2017-09-07T00:00:00.0000000Z         10299
# 1  2017-09-09T00:00:00.0000000Z  2017-09-08T00:00:00.0000000Z          9631
#
#    volume_traded name
# 0  195531.523627  NEO
# 1  296027.175577  NEO

# %%
csv6_file = "NEO.csv"
df6.to_csv(csv6_file, sep = "\t")

# %%
new_df = new_df.append(df6, ignore_index=True)
new_df.tail(2)
# Out:
#      cc_ID  measurement_ID name  price_close  price_high  price_low  \
# 698   99.0             NaN  NEO       49.989      54.780     42.596
# 699  100.0             NaN  NEO       47.950      51.276     41.273
#
#      price_open               time_period_end             time_period_start  \
# 698      44.500  2017-12-15T00:00:00.0000000Z  2017-12-14T00:00:00.0000000Z
# 699      49.985  2017-12-16T00:00:00.0000000Z  2017-12-15T00:00:00.0000000Z
#
#      trades_count  volume_traded
# 698         46537   1.064170e+06
# 699         26376   6.067296e+05

# %%
df7 = pd.read_sql_query("select * from xmr", conn)

# %%
df7['name'] = 'XMR'
df7.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       13.694      13.695     12.718      13.403
# 1      2       13.339      13.965     13.339      13.533
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-01-10T00:00:00.0000000Z  2017-01-09T00:00:00.0000000Z           321
# 1  2017-01-11T00:00:00.0000000Z  2017-01-10T00:00:00.0000000Z            83
#
#    volume_traded name
# 0    4429.701551  XMR
# 1    1247.088031  XMR

# %%
csv7_file = "xmr.csv"
df7.to_csv(csv7_file, sep = "\t")

# %%
new_df = new_df.append(df7, ignore_index=True)
new_df.tail(2)
# Out:
#      cc_ID  measurement_ID name  price_close  price_high  price_low  \
# 798   99.0             NaN  XMR       27.413      27.537     24.429
# 799  100.0             NaN  XMR       27.250      27.960     25.403
#
#      price_open               time_period_end             time_period_start  \
# 798      24.829  2017-05-04T00:00:00.0000000Z  2017-05-03T00:00:00.0000000Z
# 799      27.483  2017-05-05T00:00:00.0000000Z  2017-05-04T00:00:00.0000000Z
#
#      trades_count  volume_traded
# 798          2608   38335.195682
# 799          2761   59745.254347

# %%
df8 = pd.read_sql_query("select * from usdt", conn)

# %%
df8['name'] = 'USDT'
df8.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       0.9983       1.001     0.9901      1.0009
# 1      2       1.0008       1.001     0.9946      0.9983
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-04-02T00:00:00.0000000Z  2017-04-01T00:00:00.0000000Z          2775
# 1  2017-04-03T00:00:00.0000000Z  2017-04-02T00:00:00.0000000Z         12844
#
#    volume_traded  name
# 0  568085.462489  USDT
# 1  881231.832307  USDT

# %%
csv8_file = "usdt.csv"
df8.to_csv(csv8_file, sep = "\t")

# %%
new_df = new_df.append(df8, ignore_index=True)
new_df.tail(2)
# Out:
#      cc_ID  measurement_ID  name  price_close  price_high  price_low  \
# 898   99.0             NaN  USDT       1.0061      1.0160     1.0054
# 899  100.0             NaN  USDT       1.0106      1.0106     1.0060
#
#      price_open               time_period_end             time_period_start  \
# 898      1.0098  2017-07-09T00:00:00.0000000Z  2017-07-08T00:00:00.0000000Z
