# %%
import pandas as pd
import os
import csv
import sqlite3
import sqlalchemy
from sqlalchemy import create_engine, MetaData

# %%
engine = create_engine("sqlite:///cryptocurrency.sqlite")
conn = sqlite3.connect("cryptocurrency.sqlite")

# %%
df = pd.read_sql_query("select * from bch", conn)

# %%
df['name'] = 'BCH'
df.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       2498.0      2500.0    2432.00     2436.01
# 1      2       2600.0      2895.0    2298.57     2490.63
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-12-29T00:00:00.0000000Z  2017-12-28T00:00:00.0000000Z           689
# 1  2017-12-30T00:00:00.0000000Z  2017-12-29T00:00:00.0000000Z         15691
#
#    volume_traded name
# 0     413.643122  BCH
# 1   11900.499231  BCH

# %%
df.count()
# Out:
# cc_ID                157
# price_close          157
# price_high           157
# price_low            157
# price_open           157
# time_period_end      157
# time_period_start    157
# trades_count         157
# volume_traded        157
# name                 157
# dtype: int64

# %%
csv_file = "bch.csv"

# %%
df.to_csv(csv_file, sep='\t')

# %%
df1 = pd.read_sql_query("select * from btc", conn)

# %%
df1['name'] = 'BTC'
df1.head(2)
# Out:
#    CC_ID  price_close  price_high  price_low  price_open  \
# 0      1       536.95      542.87     525.49      532.37
# 1      2       538.00      540.00     529.13      536.95
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2016-06-02T00:00:00.0000000Z  2016-06-01T00:00:00.0000000Z          4433
# 1  2016-06-03T00:00:00.0000000Z  2016-06-02T00:00:00.0000000Z          3533
#
#    volume_traded name
# 0    5456.942657  BTC
# 1    3939.351328  BTC

# %%
df1.count()
# Out:
# CC_ID                732
# price_close          732
# price_high           732
# price_low            732
# price_open           732
# time_period_end      732
# time_period_start    732
# trades_count         732
# volume_traded        732
# name                 732
# dtype: int64

# %%
csv1_file = "btc.csv"
df1.to_csv(csv1_file, sep = "\t")

# %%
new_df = df.append(df1, ignore_index=True)
new_df.tail(2)
# Out:
#      CC_ID  cc_ID name  price_close  price_high  price_low  price_open  \
# 887  731.0    NaN  BTC       7511.6     7620.01    7348.45     7492.28
# 888  732.0    NaN  BTC       7642.0     7700.00    7438.92     7511.72
#
#                   time_period_end             time_period_start  trades_count  \
# 887  2018-06-02T00:00:00.0000000Z  2018-06-01T00:00:00.0000000Z         23273
# 888  2018-06-03T00:00:00.0000000Z  2018-06-02T00:00:00.0000000Z         21207
#
#      volume_traded
# 887    6762.627573
# 888    4012.168755

# %%
df2 = pd.read_sql_query("select * from eth", conn)

# %%
df2['name'] = 'ETH'
df2.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       298.40       298.6     292.30      293.13
# 1      2       319.31       353.0     292.71      297.26
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-08-21T00:00:00.0000000Z  2017-08-20T00:00:00.0000000Z           202
# 1  2017-08-22T00:00:00.0000000Z  2017-08-21T00:00:00.0000000Z          9772
#
#    volume_traded name
# 0     289.702776  ETH
# 1   24750.689250  ETH

# %%
csv2_file = "eth.csv"
df2.to_csv(csv2_file, sep = "\t")

# %%
new_df = new_df.append(df2, ignore_index=True)
new_df.tail(2)
# Out:
#       CC_ID  cc_ID name  price_close  price_high  price_low  price_open  \
# 1174    NaN  286.0  ETH       578.96       589.0     563.38      576.48
# 1175    NaN  287.0  ETH       591.00       599.5     573.32      578.99
#
#                    time_period_end             time_period_start  \
# 1174  2018-06-02T00:00:00.0000000Z  2018-06-01T00:00:00.0000000Z
# 1175  2018-06-03T00:00:00.0000000Z  2018-06-02T00:00:00.0000000Z
#
#       trades_count  volume_traded
# 1174          8130   22076.537570
# 1175          6058   15555.642657

# %%
df3 = pd.read_sql_query("select * from ltc", conn)

# %%
df3['name'] = 'LTC'
df3.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1        42.04       42.99      40.55        41.7
# 1      2        40.50       41.97      39.64        41.8
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-06-29T00:00:00.0000000Z  2017-06-28T00:00:00.0000000Z           811
# 1  2017-06-30T00:00:00.0000000Z  2017-06-29T00:00:00.0000000Z           672
#
#    volume_traded name
# 0   18559.116545  LTC
# 1   14557.531222  LTC

# %%
csv3_file = "ltc.csv"
df3.to_csv(csv3_file, sep = "\t")

# %%
new_df = new_df.append(df3, ignore_index=True)
new_df.tail(2)
# Out:
#       CC_ID  cc_ID name  price_close  price_high  price_low  price_open  \
# 1514    NaN  339.0  LTC       120.23      120.37     116.93      118.00
# 1515    NaN  340.0  LTC       123.52      124.27     118.56      120.24
#
#                    time_period_end             time_period_start  \
# 1514  2018-06-02T00:00:00.0000000Z  2018-06-01T00:00:00.0000000Z
# 1515  2018-06-03T00:00:00.0000000Z  2018-06-02T00:00:00.0000000Z
#
#       trades_count  volume_traded
# 1514          1066    6845.469169
# 1515          1268    7696.174314

# %%
df4 = pd.read_sql_query("select * from xrp", conn)

# %%
df4['name'] = 'XRP'
df4.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1      0.00649      0.0065    0.00645     0.00645
# 1      2      0.00638      0.0065    0.00638     0.00650
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-01-26T00:00:00.0000000Z  2017-01-25T00:00:00.0000000Z            52
# 1  2017-01-27T00:00:00.0000000Z  2017-01-26T00:00:00.0000000Z            30
#
#    volume_traded name
# 0  535232.116769  XRP
# 1  366651.319173  XRP

# %%
csv4_file = "xrp.csv"
df4.to_csv(csv4_file, sep = "\t")

# %%
new_df = new_df.append(df4, ignore_index=True)
new_df.tail(2)
# Out:
#       CC_ID  cc_ID name  price_close  price_high  price_low  price_open  \
# 1998    NaN  483.0  XRP      0.61909     0.62457    0.60521     0.61117
# 1999    NaN  484.0  XRP      0.64291     0.65050    0.61400     0.61977
#
#                    time_period_end             time_period_start  \
# 1998  2018-06-02T00:00:00.0000000Z  2018-06-01T00:00:00.0000000Z
# 1999  2018-06-03T00:00:00.0000000Z  2018-06-02T00:00:00.0000000Z
#
#       trades_count  volume_traded
# 1998          3182   8.066204e+06
# 1999          5915   1.205968e+07

# %%
df5 = pd.read_sql_query("select * from etc", conn)

# %%
df5['name'] = 'ETC'
df5.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       1.7275      1.9659      1.685      1.7943
# 1      2       1.6430      1.7990      1.550      1.7289
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2016-07-29T00:00:00.0000000Z  2016-07-28T00:00:00.0000000Z          4288
# 1  2016-07-30T00:00:00.0000000Z  2016-07-29T00:00:00.0000000Z          8121
#
#    volume_traded name
# 0  194328.318400  ETC
# 1  494860.563079  ETC

# %%
csv5_file = "etc.csv"
df5.to_csv(csv5_file, sep = "\t")

# %%
new_df = new_df.append(df5, ignore_index=True)
new_df.tail(2)
# Out:
#       CC_ID  cc_ID name  price_close  price_high  price_low  price_open  \
# 2657    NaN  658.0  ETC       15.485      15.526     15.080      15.292
# 2658    NaN  659.0  ETC       15.846      16.150     15.299      15.486
#
#                    time_period_end             time_period_start  \
# 2657  2018-06-02T00:00:00.0000000Z  2018-06-01T00:00:00.0000000Z
# 2658  2018-06-03T00:00:00.0000000Z  2018-06-02T00:00:00.0000000Z
#
#       trades_count  volume_traded
# 2657          7253  233858.123460
# 2658          6470  351155.137162

# %%
df6 = pd.read_sql_query("select * from neo", conn)

# %%
df6['name'] = 'NEO'
df6.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1        31.15       39.80     28.144      34.950
# 1      2        25.89       31.39     22.320      31.003
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-09-08T00:00:00.0000000Z  2017-09-07T00:00:00.0000000Z         10299
# 1  2017-09-09T00:00:00.0000000Z  2017-09-08T00:00:00.0000000Z          9631
#
#    volume_traded name
# 0  195531.523627  NEO
# 1  296027.175577  NEO

# %%
csv6_file = "NEO.csv"
df6.to_csv(csv6_file, sep = "\t")

# %%
new_df = new_df.append(df6, ignore_index=True)
new_df.tail(2)
# Out:
#       CC_ID  cc_ID name  price_close  price_high  price_low  price_open  \
# 2926    NaN  268.0  NEO       55.622       56.25     52.859      53.062
# 2927    NaN  269.0  NEO       56.738       57.61     54.780      55.690
#
#                    time_period_end             time_period_start  \
# 2926  2018-06-02T00:00:00.0000000Z  2018-06-01T00:00:00.0000000Z
# 2927  2018-06-03T00:00:00.0000000Z  2018-06-02T00:00:00.0000000Z
#
#       trades_count  volume_traded
# 2926          6594  118195.779891
# 2927          6454  116055.432898

# %%
df7 = pd.read_sql_query("select * from xmr", conn)

# %%
df7['name'] = 'XMR'
df7.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       13.694      13.695     12.718      13.403
# 1      2       13.339      13.965     13.339      13.533
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-01-10T00:00:00.0000000Z  2017-01-09T00:00:00.0000000Z           321
# 1  2017-01-11T00:00:00.0000000Z  2017-01-10T00:00:00.0000000Z            83
#
#    volume_traded name
# 0    4429.701551  XMR
# 1    1247.088031  XMR

# %%
csv7_file = "xmr.csv"
df7.to_csv(csv7_file, sep = "\t")

# %%
new_df = new_df.append(df7, ignore_index=True)
new_df.tail(2)
# Out:
#       CC_ID  cc_ID name  price_close  price_high  price_low  price_open  \
# 3420    NaN  493.0  XMR       157.51      158.59     152.67      155.22
# 3421    NaN  494.0  XMR       162.63      167.98     155.94      157.52
#
#                    time_period_end             time_period_start  \
# 3420  2018-06-02T00:00:00.0000000Z  2018-06-01T00:00:00.0000000Z
# 3421  2018-06-03T00:00:00.0000000Z  2018-06-02T00:00:00.0000000Z
#
#       trades_count  volume_traded
# 3420          1883    8518.272947
# 3421          3594   21515.734784

# %%
df8 = pd.read_sql_query("select * from usdt", conn)

# %%
df8['name'] = 'USDT'
df8.head(2)
# Out:
#    cc_ID  price_close  price_high  price_low  price_open  \
# 0      1       0.9983       1.001     0.9901      1.0009
# 1      2       1.0008       1.001     0.9946      0.9983
#
#                 time_period_end             time_period_start  trades_count  \
# 0  2017-04-02T00:00:00.0000000Z  2017-04-01T00:00:00.0000000Z          2775
# 1  2017-04-03T00:00:00.0000000Z  2017-04-02T00:00:00.0000000Z         12844
#
#    volume_traded  name
# 0  568085.462489  USDT
# 1  881231.832307  USDT

# %%
csv8_file = "usdt.csv"
df8.to_csv(csv8_file, sep = "\t")

# %%
new_df = new_df.append(df8, ignore_index=True)
new_df.tail(2)
# Out:
#       CC_ID  cc_ID  name  price_close  price_high  price_low  price_open  \
# 3847    NaN  426.0  USDT       0.9987      0.9997     0.9983      0.9989
# 3848    NaN  427.0  USDT       0.9999      0.9999     0.9954      0.9987
#
#                    time_period_end             time_period_start  \
# 3847  2018-06-02T00:00:00.0000000Z  2018-06-01T00:00:00.0000000Z
# 3848  2018-06-03T00:00:00.0000000Z  2018-06-02T00:00:00.0000000Z
#
#       trades_count  volume_traded
# 3847           515   6.137875e+05
# 3848         12681   3.211059e+08

# %%
all_cryptoCurr_df = new_df[['name', 'price_high','price_low','price_open','price_close', 'time_period_start','time_period_end', 'volume_traded','trades_count']]
all_cryptoCurr_df.head()
# Out:
#   name  price_high  price_low  price_open  price_close  \
# 0  BCH     2500.00    2432.00     2436.01      2498.00
# 1  BCH     2895.00    2298.57     2490.63      2600.00
# 2  BCH     2628.91    2120.00     2600.00      2240.42
# 3  BCH     2504.00    2189.00     2232.58      2377.00
# 4  BCH     2410.00    2250.00     2377.00      2310.00
#
#               time_period_start               time_period_end  volume_traded  \
# 0  2017-12-28T00:00:00.0000000Z  2017-12-29T00:00:00.0000000Z     413.643122
# 1  2017-12-29T00:00:00.0000000Z  2017-12-30T00:00:00.0000000Z   11900.499231
# 2  2017-12-30T00:00:00.0000000Z  2017-12-31T00:00:00.0000000Z    9515.133242
# 3  2017-12-31T00:00:00.0000000Z  2018-01-01T00:00:00.0000000Z    3199.328529
# 4  2018-01-01T00:00:00.0000000Z  2018-01-02T00:00:00.0000000Z    2772.401786
#
#    trades_count
# 0           689
# 1         15691
# 2         11876
# 3          5188
# 4          2629

# %%
csv9_file = "allcryptocurr.csv"
all_cryptoCurr_df.to_csv(csv9_file, sep = "\t")
